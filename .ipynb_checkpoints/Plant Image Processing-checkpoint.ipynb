# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import pandas as pd

# %% [markdown]
# # Segmentation

# %%
from PIL import Image
img0 = Image.open('C:/Users/ASUS/Desktop/healthy.png').convert('L')
image0_segmented = img0.resize((28,28))
img1 = Image.open('C:/Users/ASUS/Desktop/0c4e75b2-e4aa-437e-815c-636271d66bec___JR_B.Spot 3244.jpg').convert('L')
image1 = img1.resize((28,28))
img1_segmented = Image.open('C:/Users/ASUS/Desktop/graph cut.png').convert('L')
image1_segmented = img1_segmented.resize((28,28))

# %%
image0_segmented
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x165E8165B88>

# %%
image1_segmented
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x165E8165B48>

# %%
image1
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x165E82F4B08>

# %%
data0_segmented = asarray(image0_segmented)
data1 = asarray(image1)
data1_segmented = asarray(image1_segmented)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1332\256292224.py in <module>
# ----> 1 data0_segmented = asarray(image0_segmented)
#       2 data1 = asarray(image1)
#       3 data1_segmented = asarray(image1_segmented)
#
# NameError: name 'asarray' is not defined

# %%
def display(data, txt):
    np.set_printoptions(linewidth=200, precision=2)
    print(data)
    plt.imshow(data, cmap = 'gray')
    plt.axis('off')
    plt.title(txt)

# %%
display(data1_segmented,"Bacterial spot segmented")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1332\2574553416.py in <module>
# ----> 1 display(data1_segmented,"Bacterial spot segmented")
#
# NameError: name 'data1_segmented' is not defined

# %%
display(data1,"Bacterial spot")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1332\3992696891.py in <module>
# ----> 1 display(data1,"Bacterial spot")
#
# NameError: name 'data1' is not defined

# %%
display(data0_segmented,"Healthy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1332\3387402824.py in <module>
# ----> 1 display(data0_segmented,"Healthy")
#
# NameError: name 'data0_segmented' is not defined

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Random Brightness

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255, brightness_range=[0.1,1.0])
train_generator = train_datagen.flow_from_directory("D:/PlantVillage/", target_size = (256,256), batch_size = 20)
plt.figure(figsize=(12, 12))
for i in range(0, 12):
    plt.subplot(4, 3, i+1)
    for X_batch, Y_batch in train_generator:
        image = X_batch[0]
        plt.imshow(image)
        plt.axis('off')
        break
plt.tight_layout()
plt.show()
# Out:
# Found 20638 images belonging to 15 classes.

# %% [markdown]
# # Random Zoom and Rotation

# %%
train_datagen = ImageDataGenerator(rescale = 1.0/255, rotation_range = 30, shear_range = 0.2, horizontal_flip = True, fill_mode = 'nearest', width_shift_range = 0.1, height_shift_range = 0.1, zoom_range=[0.5,1.0])
train_generator = train_datagen.flow_from_directory("D:/PlantVillage/", target_size = (256,256), batch_size = 20)
plt.figure(figsize=(12, 12))
for i in range(0, 12):
    plt.subplot(4, 3, i+1)
    for X_batch, Y_batch in train_generator:
        image = X_batch[0]
        plt.imshow(image)
        plt.axis('off')
        break
plt.tight_layout()
plt.show()
# Out:
# Found 20638 images belonging to 15 classes.
